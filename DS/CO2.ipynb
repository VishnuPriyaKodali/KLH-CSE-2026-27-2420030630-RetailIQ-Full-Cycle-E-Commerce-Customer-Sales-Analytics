# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\vishu\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vishu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.title("Line Graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('simple graph')
plt.axhline()
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('simple graph')
plt.axvline()
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('simple graph')
plt.axhline()
plt.axvline()
plt.savefig("linegraph.jpg")
plt.show()

# %%
import matplotlib.pyplot as plt
y1=[]
y2=[]
x=range(-100,100,10)
for i in x:
    y1.append(i**2)
for i in x:
    y2.append(-i**2)
plt.plot(x,y1)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('simple graph')
plt.axhline(color='red')
plt.axvline(color='green')
plt.savefig("linegraph.jpg")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='red')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.savefig('dataset.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='purple')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.savefig('dataset.jpg')
plt.show()

# %%
plt.plot(df['Mes'],df['data science'],label='data science')
plt.plot(df['Mes'],df['machine learning'],label='machine learning')
plt.plot(df['Mes'],df['deep learning'],label='deep learning')
plt.xlabel('Date')
plt.ylabel('Popularity')
plt.title('Popularity of AI terms by date')
plt.grid(True)
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='cyan')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.xlim(10,100)
plt.ylim(0,50)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.plot(df['deep learning'],df['machine learning'],color='brown')
plt.xlabel('deep learning')
plt.ylabel('machine learning')
plt.title('line plot')
plt.xlim(10,100)
plt.ylim(0,50)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[0,1,2,3,4,5]
y_values=[0,1,4,9,16,25]
plt.scatter(x_values,y_values,color="pink")
plt.title('Scatter Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.scatter(df['deep learning'],df['machine learning'],color = 'red', marker="^")
plt.title('Scatter Plot')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.scatter(df['deep learning'],df['machine learning'],color = 'red', marker="*")
plt.title('Scatter Plot')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ["A","B","C","D","E"]
plt.bar(names,values,color = 'purple')
plt.title("Bar Graph")
plt.xlabel("Names")
plt.ylabel("Values")
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ["A","B","C","D","E"]
plt.barh(names,values,color = 'purple')
plt.title("Bar Graph")
plt.xlabel("Values")
plt.ylabel("Names")
plt.show()

# %%
import matplotlib.pyplot as plt
values = [5,6,3,7,2]
names = ["A","B","C","D","E"]
c1 = ['red','purple']
c2 = ['b','g','y']
plt.bar(names,values, width=0.5,color=c1)
plt.show()
plt.barh(names,values,height=0.5,color=c2)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("temporal.csv")
plt.bar(df['deep learning'],df['machine learning'],color = 'pink')
plt.title('bar graph')
plt.xlabel("Deep Learning")
plt.ylabel("Machine Learning")
plt.show()

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\vishu\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vishu\anaconda3\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\vishu\anaconda3\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vishu\anaconda3\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishu\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vishu\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vishu\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vishu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
sns.set_style(style=darkgrid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 data = sns.load_dataset("iris")
#       3 sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# ----> 4 sns.set_style(style=darkgrid)
#
# NameError: name 'darkgrid' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(x='sex', data=df,palette='Set1')
plt.show()
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\980079610.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(x='sex', data=df,palette='Set2')
plt.show()
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\2972240585.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=df,palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(y='sex', data=df,palette='Set2')
plt.show()
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\2132152983.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='sex', data=df,palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(x='sex',data=df,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(x="sex",hue='day',data=df,palette='Set1')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("tips.csv")
sns.countplot(y="sex",hue='day',data=df,palette='Set1')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("Iris.csv")
sns.countplot(x="Species",data=df,palette='Set1')
plt.show()
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\1028339137.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Species",data=df,palette='Set1')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("whitegrid")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("darkgrid")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("darkgrid")
sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.set_style("darkgrid")
sns.despine(left=True,right=False);
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("tips")
sns.pairplot(data,hue='day')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("tips")
p={'Male':'lightblue', 'Female':'Pink'}
sns.pairplot(data,hue='sex', palette=p)
plt.show()

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,shade=True)
sns.kdeplot(y)
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\1388057297.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True)
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x,vertical=True)
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\978006440.py:5: UserWarning:
#
# The `vertical` parameter is deprecated; assigning data to `y`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,vertical=True)
# <Axes: xlabel='Density'>

# %%
import seaborn as sns
import numpy as np
x=np.random.randn(200)
y=np.random.randn(200)
sns.kdeplot(x=x,y=y)
# Out:
# <Axes: >

# %%
import seaborn as sns
df=sns.load_dataset('iris')
sns.kdeplot(x=df['petal_length'])
sns.kedeplot(x=df['petal_width'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 4
#       2 df=sns.load_dataset('iris')
#       3 sns.kdeplot(x=df['petal_length'])
# ----> 4 sns.kedeplot(x=df['petal_width'])
#
# AttributeError: module 'seaborn' has no attribute 'kedeplot'

# %%
import seaborn as sns
df=sns.load_dataset('iris')
sns.kdeplot(x=df['petal_length'])
sns.kdeplot(x=df['petal_width'],shade=True)
# Out:
# C:\Users\vishu\AppData\Local\Temp\ipykernel_47624\1344654871.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=df['petal_width'],shade=True)
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
import seaborn as sns
df=sns.load_dataset('iris')
sns.kdeplot(x=df['petal_length'],y=df['petal_width'])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.displot(data['total_bill'],kde=False,color='red',bins=30)

# %%
import seaborn as sns
df=sns.load_dataset("tips")
sns.displot(data['total_bill'],kde=True,color='red',bins=30)

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.jointplot(x='total_bill',y='tip',data=data)

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.countplot(x='sex',hue='smoker',data=data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.countplot(y='sex',hue='smoker',data=data)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.boxplot(data['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.boxplot(data['tip'])
# Out:
# <Axes: ylabel='tip'>

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.boxplot(data['size'])
# Out:
# <Axes: ylabel='size'>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('temporal.csv')
sns.boxplot(df['data science'])
# Out:
# <Axes: ylabel='data science'>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('temporal.csv')
sns.boxplot(df['deep learning'])
# Out:
# <Axes: ylabel='deep learning'>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv('temporal.csv')
sns.boxplot(df['machine learning'])
# Out:
# <Axes: ylabel='machine learning'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv('temporal.csv')
q1=np.percentile(df['data science'], 25, method='midpoint')
q3=np.percentile(df['data science'], 75, method='midpoint')
iqr=q3-q1
print("The O/P of IQR")
print(iqr)
# Out:
# The O/P of IQR
# 20.5

# %%
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv('temporal.csv')
q1=np.percentile(df['data science'], 25, method='midpoint')
q3=np.percentile(df['data science'], 75, method='midpoint')
iqr=q3-q1
print("The O/P of IQR")
print(iqr)
upper=q3+1.5*iqr
upper_array=np.array(df['data science']>=upper)
print("Upper Bound:", upper)
print(upper_array.sum())
# Out:
# The O/P of IQR
# 20.5
# Upper Bound: 57.25
# 24

# %%
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv('temporal.csv')
q1=np.percentile(df['data science'], 25, method='midpoint')
q3=np.percentile(df['data science'], 75, method='midpoint')
iqr=q3-q1
print("The O/P of IQR")
print(iqr)
lower=q1-1.5*iqr
lower_array=np.array(df['data science']<=lower)
print("Lower Bound:", lower)
print(lower_array.sum())
# Out:
# The O/P of IQR
# 20.5
# Lower Bound: -24.75
# 0

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,vmin=30,vmax=70)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='tab20',annot=True)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=np.random.randint(1,100,(10,10))
sns.heatmap(data,cmap='coolwarm',center=50)
plt.show()

# %%
import seaborn as sns
data=sns.load_dataset("tips")
sns.heatmap(data[['tip']])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
data=[12,15,20,20,22,23,25,25,30,32,35,40]
plt.hist(data,bins=5,color='purple',edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("tips")
plt.hist(data['total_bill'],bins=10,color='green',edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('iris')
sns.violinplot(x='species',y='petal_length',data=df)
plt.title('Violin Plot')
plt.show()

# %%
pip install dash
# Out:
# Collecting dash
#   Downloading dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\vishu\anaconda3\lib\site-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\vishu\anaconda3\lib\site-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\vishu\anaconda3\lib\site-packages (from dash) (6.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\vishu\anaconda3\lib\site-packages (from dash) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\vishu\anaconda3\lib\site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in c:\users\vishu\anaconda3\lib\site-packages (from dash) (2.32.5)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in c:\users\vishu\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\vishu\anaconda3\lib\site-packages (from dash) (80.9.0)
# Collecting janus>=1.0.0 (from dash)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic>=2.10 in c:\users\vishu\anaconda3\lib\site-packages (from dash) (2.12.4)
# Requirement already satisfied: comm in c:\users\vishu\anaconda3\lib\site-packages (from dash) (0.2.3)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\vishu\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\vishu\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\vishu\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\vishu\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\vishu\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: colorama in c:\users\vishu\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\vishu\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (2.7.0)
# Requirement already satisfied: packaging in c:\users\vishu\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vishu\anaconda3\lib\site-packages (from pydantic>=2.10->dash) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\vishu\anaconda3\lib\site-packages (from pydantic>=2.10->dash) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\vishu\anaconda3\lib\site-packages (from pydantic>=2.10->dash) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\vishu\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vishu\anaconda3\lib\site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishu\anaconda3\lib\site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vishu\anaconda3\lib\site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vishu\anaconda3\lib\site-packages (from requests->dash) (2026.6.17)
# Downloading dash-4.4.1-py3-none-any.whl (8.9 MB)
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    --------------- ------------------------ 3.4/8.9 MB 17.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.9 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 14.9 MB/s  0:00:00
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: retrying, janus, dash
#
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    -------------------------- ------------- 2/3 [dash]
#    ---------------------------------------- 3/3 [dash]
#
# Successfully installed dash-4.4.1 janus-2.0.0 retrying-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
app=dash.Dash(__name__)
app.layout=html.Div([
    html.H1("Dash Tutorial"),
    dcc.Graph(
        id="example",
        figure={
            "data": [
                {
                    "x": [1,2,3,4,5],
                    "y": [5,4,7,4,8],
                    "type": "line",
                    "name": "Trucks"
                },
                {
                    "x": [1,2,3,4,5],
                    "y": [6,3,5,3,7],
                    "type": "bar",
                    "name": "Ships"
                }
            ],
            "layout" : {
                "title": "Basic Dashboard"
            }
        }
    )
])
app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
